# %% [markdown]
# # Projeto de Redes Sociais

# %% [markdown]
# ### Diferencas nas Redes Sociais de Game of Thrones no livro e na serie

# %% [markdown]
# ---
# ***
# ___
# ### LIVRO:

# %% [markdown]
# ##### Carregando datasets do livro:

# %%
import pandas as pd

# dataset do livro 1
book1 = pd.read_csv('data_new/book1-edges.csv')
book1.head()

# dataset do livro 2
book2 = pd.read_csv('data_new/book2-edges.csv')
book2.head()

# dataset do livro 3
book3 = pd.read_csv('data_new/book3-edges.csv')
book3.head()

# dataset do livro 4
book4 = pd.read_csv('data_new/book4-edges.csv')
book4.head()

# dataset do livro 5
book5 = pd.read_csv('data_new/book5-edges.csv')
book5.head()
# Out:
#                    Source            Target        Type  Weight  book
# 0                   AEGON          DAENERYS  UNDIRECTED       4     5
# 1  AEGON-(SON-OF-RHAEGAR)          DAENERYS  UNDIRECTED      11     5
# 2  AEGON-(SON-OF-RHAEGAR)              ELIA  UNDIRECTED       4     5
# 3  AEGON-(SON-OF-RHAEGAR)  FRANKLYN-FLOWERS  UNDIRECTED       3     5
# 4  AEGON-(SON-OF-RHAEGAR)            HALDON  UNDIRECTED      14     5

# %% [markdown]
# Essa tabela apresenta as relacoes entre os personagens, sendo definidas pela presenca dos nomes de ambos com uma distancia de no maximo 15 palavras entre si.
#
# As colunas Source e Target apresentam os personagens ligados entre si, a coluna Type determina o tipo de ligacao, sendo para este caso sempre nao direcionada. A coluna Weight apresenta o numero de ocorrencias de uma relacao entre os dois personagens no livro especificado pela coluna livro. Nesse caso, como estamos carregando os datasets de cada livro separadamente, a coluna livro nao tem muito proposito.
#
# Observacao: As relacoes com Weight menor de 3 foram cortadas da tabela por serem consideradas acidentais em sua maioria.

# %% [markdown]
# ##### Criando as redes dos livros

# %%
import networkx as nx
import freeman as fm
from random import randint

def criar_grafo(csv):
    g1 = fm.Graph(nx.empty_graph())
    for n, edge in csv.iterrows():
        #print("NODEx: ", edge['Source'])
        #print("NODEy: ", edge['Target'])
        #print("EDGE_WEIGHT: ", edge['weight'])
        if(edge['Source'] not in g1):
            g1.add_node(edge['Source'], pos = [randint(0,800), randint(0,450)], label = edge['Source'])
        if(edge['Target'] not in g1):
            g1.add_node(edge['Target'], pos = [randint(0,800), randint(0,450)], label = edge['Target'])

    for n, edge in csv.iterrows():  
        g1.add_edge(edge['Source'], edge['Target'], weight=edge['Weight'])
        
    return g1
    

    
g1 = criar_grafo(book1)
g2 = criar_grafo(book2)
g3 = criar_grafo(book3)
g4 = criar_grafo(book4)
g5 = criar_grafo(book5)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# C:\Users\elijo\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:23: FutureWarning:
#
# The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version

# %% [markdown]
# ##### Plotando o grafo do livro 1

# %%
g1.set_all_nodes('size', 12)
g1.set_all_nodes('labpos', 'hover')
g1.set_nodedata('degree', g1.degree)
g1.distest_nodes('degree')
g1.displot_nodes('degree')
#g1.move('step')
g1.move('kamada_kawai')
g1.scale_nodes_size(g1.degree)
#g1.color_nodes()
g1.draw()
# Out:
# <div>
#
#
#             <div id="c257932a-92b4-4a58-9aee-771fa5c69e39" class="plotly-graph-div" style="height:450px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c257932a-92b4-4a58-9aee-771fa5c69e39")) {
#                     Plotly.newPlot(
#                         'c257932a-92b4-4a58-9aee-771fa5c69e39',
#                         [{"hoverinfo": "none", "line": {"color": "rgb(127, 127, 127)", "dash": "solid", "width": 0}, "mode": "lines", "type": "scatter", "x": [0.4201736972524465, 0.4201736972524465, null, 0, 1, null], "y": [0, 1, null, 0.4393639528647879, 0.4393639528647879, null]}, {"hoverinfo": "none", "line": {"color": "rgb(0, 0, 0)", "dash": "solid", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.33850330801523143, 0.40631374207048127, null, 0.33850330801523143, 0.3340552684234531, null, 0.40631374207048127, 0.48439918409898625, null, 0.40631374207048127, 0.4906928710005168, null, 0.40631374207048127, 0.2973822355842708, null, 0.40631374207048127, 0.26370664717661935, null, 0.40631374207048127, 0.5342368950452829, null, 0.40631374207048127, 0.3343768045481994, null, 0.40631374207048127, 0.3097403988560454, null, 0.40631374207048127, 0.33226417167193284, null, 0.40631374207048127, 0.4544360794584496, null, 0.40631374207048127, 0.41741715632097576, null, 0.40631374207048127, 0.3829819003914785, null, 0.40631374207048127, 0.5146783549839415, null, 0.40631374207048127, 0.4621254666305232, null, 0.40631374207048127, 0.4708513968000034, null, 0.40631374207048127, 0.4646480205733282, null, 0.40631374207048127, 0.36479029327369283, null, 0.40631374207048127, 0.4270877382882423, null, 0.40631374207048127, 0.4182860137062452, null, 0.40631374207048127, 0.36043914365500684, null, 0.40631374207048127, 0.3647302130388317, null, 0.40631374207048127, 0.5061170644365892, null, 0.40631374207048127, 0.43595642596760226, null, 0.40631374207048127, 0.47839311900944265, null, 0.40631374207048127, 0.4472519789108818, null, 0.40631374207048127, 0.39990157749002153, null, 0.40631374207048127, 0.3340552684234531, null, 0.40631374207048127, 0.3902554485486085, null, 0.40631374207048127, 0.36878021950713047, null, 0.3340552684234531, 0.2966256916124221, null, 0.3340552684234531, 0.2973822355842708, null, 0.3340552684234531, 0.26370664717661935, null, 0.3340552684234531, 0.5342368950452829, null, 0.3340552684234531, 0.3343768045481994, null, 0.3340552684234531, 0.4544360794584496, null, 0.3340552684234531, 0.3829819003914785, null, 0.3340552684234531, 0.25375676669573155, null, 0.3340552684234531, 0.4708513968000034, null, 0.3340552684234531, 0.28965526870435077, null, 0.3340552684234531, 0.37988582225857737, null, 0.3340552684234531, 0.4576385641489934, null, 0.3340552684234531, 0.3647302130388317, null, 0.3340552684234531, 0.5061170644365892, null, 0.3340552684234531, 0.27575719865937975, null, 0.3340552684234531, 0.4175902197909116, null, 0.3340552684234531, 0.375251674154633, null, 0.3340552684234531, 0.39990157749002153, null, 0.3340552684234531, 0.3902554485486085, null, 0.3340552684234531, 0.24264753577869513, null, 0.3179174216536769, 0.4160935039468596, null, 0.3179174216536769, 0.3343768045481994, null, 0.4160935039468596, 0.5942237959072194, null, 0.4160935039468596, 0.4792032711667979, null, 0.4160935039468596, 0.6347299206091385, null, 0.4160935039468596, 0.5567110930790178, null, 0.4160935039468596, 0.3343768045481994, null, 0.4160935039468596, 0.3491558847347875, null, 0.4160935039468596, 0.5587694813631245, null, 0.4160935039468596, 0.6883319759152624, null, 0.4160935039468596, 0.6852506135082761, null, 0.4160935039468596, 0.6895077265959257, null, 0.4160935039468596, 0.6613395152019687, null, 0.4160935039468596, 0.5699283541361365, null, 0.4160935039468596, 0.6215904015542731, null, 0.4160935039468596, 0.597042284863791, null, 0.4160935039468596, 0.5534849666370583, null, 0.4160935039468596, 0.5147189695028798, null, 0.4160935039468596, 0.4576385641489934, null, 0.4160935039468596, 0.5061170644365892, null, 0.4160935039468596, 0.3902554485486085, null, 0.4160935039468596, 0.5908914133826552, null, 0.3343768045481994, 0.48439918409898625, null, 0.3343768045481994, 0.5928680276690234, null, 0.3343768045481994, 0.44253833404139153, null, 0.3343768045481994, 0.40282826102317343, null, 0.3343768045481994, 0.4906928710005168, nul ...

# %% [markdown]
# ##### Calculando Betweenness para cada livro

# %%
b_livro1 = nx.betweenness_centrality(g1)
b_livro2 = nx.betweenness_centrality(g2)
b_livro3 = nx.betweenness_centrality(g3)
b_livro4 = nx.betweenness_centrality(g4)
b_livro5 = nx.betweenness_centrality(g5)

c_livro1 = nx.closeness_centrality(g1)
c_livro2 = nx.closeness_centrality(g2)
c_livro3 = nx.closeness_centrality(g3)
c_livro4 = nx.closeness_centrality(g4)
c_livro5 = nx.closeness_centrality(g5)

p_livro1 = nx.pagerank(g1)
p_livro2 = nx.pagerank(g2)
p_livro3 = nx.pagerank(g3)
p_livro4 = nx.pagerank(g4)
p_livro5 = nx.pagerank(g5)

b_livro = [b_livro1, b_livro2, b_livro3, b_livro4, b_livro5]
c_livro = [c_livro1, c_livro2, c_livro3, c_livro4, c_livro5]
p_livro = [p_livro1, p_livro2, p_livro3, p_livro4, p_livro5]

for n in b_livro1:
    print(n, b_livro1[n])
# Out:
# ADDAM_MARBRAND 0.0
# JAIME 0.03236246971204843
# TYWIN 0.02660500536442575
# AEGON 0.0
# DAENERYS 0.08728206293757142
# NED 0.2715312267357991
# MAESTER_AEMON 0.01096360972519205
# ALLISER_THORNE 0.0049982813885293305
# BOWEN_MARSH 0.0
# CHETT 0.0
# CLYDAS 0.0
# JEOR 0.028457832400366357
# JON 0.17351262564816763
# SAM 0.014647539095422513
# AERYS 0.00043956968627317875
# BRANDON 0.0003476286776788073
# GEROLD-HIGHTOWER 0.021679733903540034
# JON_ARRYN 0.012608186049543044
# ROBERT 0.21549918160547415
# AGGO 7.424566405321929e-05
# DROGO 0.06543453498422813
# JHOGO 4.454739843193158e-05
# JORAH 0.012708453636942419
# QUARO 2.9698265621287717e-05
# RAKHARO 3.4647976558169e-05
# ALBETT 0.0
# HALDER 0.0002148174546606478
# RAST 7.919537499010059e-05
# GRENN 0.00020689791716163776
# PYPAR 7.62255484279718e-05
# TYRION 0.18828696791582564
# ALYN 0.00032146558033204864
# HARWIN 0.0003230025196522057
# JORY_CASSEL 0.017715318634025423
# TOMARD 0.00030320064149882606
# ARTHUR-DAYNE 0.0
# ARYA 0.017675359638537575
# BENJEN 0.03328836794784759
# BRAN 0.04789977131092188
# CATELYN 0.14939990587023802
# CERSEI 0.02669115185581448
# DESMOND 0.0
# ILYN_PAYNE 0.000326705072514868
# JEYNE-POOLE 6.243706796094537e-05
# JOFFREY 0.01908618031833744
# MERYN_TRANT 0.0007137192845835497
# MORDANE 0.0010789241331176376
# MYCAH 0.0
# MYRCELLA 2.8849743746393778e-05
# LITTLEFINGER 0.009202942150588662
# RICKON 9.181551766266156e-05
# ROBB 0.07407262228529347
# RODRIK 0.00971397048146364
# HOUND 0.006321602404956442
# SANSA 0.03744970152186399
# SYRIO_FOREL 0.00012559217241923408
# TOMMEN 0.0005525681132611179
# VAYON-POOLE 0.0
# YOREN 0.0002160168432629699
# ARYS-OAKHEART 0.0
# BALON 0.0
# BALON-SWANN 0.0
# RENLY 0.009656525064605053
# BARRISTAN 0.0012627581129513172
# BOROS 0.0
# PYCELLE 0.00032804377580897845
# VARYS 0.010885403762199443
# JAREMY_RYKKER 0.010869565217391304
# LUWIN 0.013396007649645493
# MANCE 0.0
# THEON 0.009884525136092174
# WAYMAR_ROYCE 0.006795991443227458
# BERIC 0.010869565217391304
# MOUNTAIN 0.002956397452584514
# LORAS 0.022662618807763782
# THOROS 0.0
# HALI 0.0
# HALLIS-MOLLEN 0.0
# HODOR 0.0
# HULLEN 0.00044644131698964927
# JOSETH 0.0
# NAN 0.0
# OSHA 0.0
# RICKARD 0.010212504040580255
# STIV 0.0
# LYANNA 3.394087499575739e-05
# BRONN 0.004214976019972488
# CHIGGEN 0.0
# MARILLION 0.0
# SHAE 0.0
# SHAGGA 0.021828225231646473
# VARDIS_EGEN 0.001213738122898944
# WILLIS-WODE 0.00039613098682949016
# BRYNDEN 0.003916337897929915
# EDMURE 0.019831956829198513
# HOSTER 0.00039917143479521137
# LYSA 0.016967692133964707
# NESTOR-ROYCE 0.0
# WALDER 0.03269101513043066
# COLEMON 0.0
# DONNEL_WAYNWOOD 0.0
# EON 0.0
# GREATJON_UMBER 0.0033275654808764543
# MASHA_HEDDLE 0.0
# MOREO-TUMITIS 0.0
# MYA-STONE 0.0
# MYCHEL-REDFORT 0.0
# STEVRON_FREY 0.0
# TYTOS-BLACKWOOD 0.010869565217391304
# WENDEL-MANDERLY 0.0
# CAYN 2.227369921596579e-05
# JANOS 0.0
# STANNIS 0.00044650410015190263
# CHELLA 0.0
# CLEMENT-PIPER 0.0
# KARYLANCE 0.010869565217391304
# COHOLLO 0.0
# HAGGO 6.9295953116338e-05
# QOTHO 0.00011879306248515084
# CONN 0.010869565217391304
# CORATT 0.0
# DOREAH 1.1879306248515087e-05
# EROEH 0.0
# ILLYRIO 0.0012067625450430895
# IRRI 9.800427655024946e-05
# JHIQUI 0.0
# MIRRI_MAZ_DUUR 4.949710936881286e-05
# RHAEGAR 0.002878378403333184
# VISERYS 0.002878962565758598
# DANWELL 0.021620337372297457
# HOSTEEN 0.0
# JARED 0.0
# DAREON 0.0
# DARYN-HORNWOOD 0.0
# TORRHEN 0.00027826803486104984
# DOLF 0.0
# DONAL-NOYE 0.0
# JOMMO 0.0
# OGO 0.010869565217391308
# RHAEGO 0.0
# DYWEN 0.0
# GALBART_GLOVER 0.0008706997439353362
# GENDRY 0.0
# HIGH_SEPTON 0.0
# HOWLAND 0.0
# JACKS 0.0
# JOSS 0.0
# MARQ-PIPER 0.006343942501231769
# PORTHER 0.0
# RAYMUN-DARRY 0.0
# TOBHO_MOTT 0.0
# TREGAR 0.0
# VARLY 0.0
# WYL-(GUARD) 0.0016554378279253542
# WYLLA 0.0
# FOGO 0.0
# ROOSE_BOLTON 2.5491011324938627e-05
# GARED 0.004363678903452867
# WILL-(PROLOGUE) 0.0
# OSWELL-WHENT 0.0
# TODDER 0.0
# GUNTHOR-SON-OF-GURN 0.0
# HARYS-SWYFT 0.0
# HEWARD 0.0
# HOBB 0.0
# HUGH 0.0
# JAFER-FLOWERS 0.0
# KEVAN 0.0
# MATTHAR 0.0
# OTHOR 0.0
# MAEGE 0.0
# JONOS_BRACKEN 0.0
# JYCK 0.0
# MORREC 0.0
# KURLEKET 0.0
# LANCEL 0.0
# LEO_LEFFORD 0.0
# MACE 0.010869565217391302
# LYN-CORBRAY 0.0
# PAXTER-REDWYNE 0.0
# MAEGOR 0.0
# MORD 0.0
# RANDYLL 0.0
# TIMETT 0.0
# ULF-SON-OF-UMAR 0.0

# %%
personagem_b_livro = []
for b in b_livro:
    personagem_b_livro.append(b["TYRION"])
    
print("TYRION - Betweenness:", personagem_b_livro)

personagem_c_livro = []
for c in c_livro:
    personagem_c_livro.append(c["TYRION"])
    
print("TYRION - Closeness:", personagem_c_livro)

personagem_p_livro = []
for p in p_livro:
    personagem_p_livro.append(p["TYRION"])
    
print("TYRION - Pagerank:", personagem_p_livro)
# Out:
# TYRION - Betweenness: [0.18828696791582564, 0.1580998132855627, 0.15239026580955364, 0.08375515896103619, 0.1990861155212145]
# TYRION - Closeness: [0.5096952908587258, 0.4473684210526316, 0.4574468085106383, 0.39882697947214074, 0.40359897172236503]
# TYRION - Pagerank: [0.0431044809459164, 0.04682795869136811, 0.036441814662617485, 0.012574716959607124, 0.029088500831475173]

# %% [markdown]
# ##### Calculando e inserindo metricas no grafo

# %%
def calcula_metricas(g1):
    g1.set_nodedata('betweenness', nx.betweenness_centrality(g1))
    g1.set_nodedata('closeness', nx.closeness_centrality(g1))
    g1.set_nodedata('pagerank', nx.pagerank(g1))


calcula_metricas(g1)
calcula_metricas(g2)
calcula_metricas(g3)
calcula_metricas(g4)
calcula_metricas(g5)
tabela_total = g1.nodeframe
g1.nodeframe.head()
# Out:
#                 degree  betweenness  closeness  pagerank
# ADDAM_MARBRAND       2     0.000000   0.323944  0.001287
# JAIME               29     0.032362   0.462312  0.014458
# TYWIN               22     0.026605   0.449878  0.011474
# AEGON                2     0.000000   0.377049  0.001266
# DAENERYS            21     0.087282   0.406181  0.027367

# %% [markdown]
# ---
# ***
# ___
# ### SERIE:

# %% [markdown]
# ##### Carregando dataset da serie:

# %%
# dataset da temporada 1
season1 = pd.read_csv('data/s1-edges.csv')
season1.head()

# dataset da temporada 2
season2 = pd.read_csv('data/s2-edges.csv')
season2.head()

# dataset da temporada 3
season3 = pd.read_csv('data/s3-edges.csv')
season3.head()

# dataset da temporada 4
season4 = pd.read_csv('data/s4-edges.csv')
season4.head()

# dataset da temporada 5
season5 = pd.read_csv('data/s5-edges.csv')
season5.head()
# Out:
#      Source  Target  Weight  Season
# 0      ARYA   JAQEN     148       5
# 1     JORAH  TYRION     141       5
# 2     BRONN   JAIME     121       5
# 3    TYRION   VARYS     110       5
# 4  DAENERYS  TYRION      98       5

# %% [markdown]
# ##### Criando as redes das temporadas

# %%
s1 = criar_grafo(season1)
s2 = criar_grafo(season2)
s3 = criar_grafo(season3)
s4 = criar_grafo(season4)
s5 = criar_grafo(season5)

# %% [markdown]
# ##### Plotando o grafo da temporada 1

# %%
s1.set_all_nodes('size', 12)
s1.set_all_nodes('labpos', 'hover')
s1.set_nodedata('degree', s1.degree)
df = s1.distest_nodes('degree')
s1.displot_nodes('degree')
#s1.move('step')
s1.move('kamada_kawai')
s1.scale_nodes_size(s1.degree)
#s1.color_nodes()
#s1.scale_nodes_dark(nx.closeness_centrality(s1))
s1.draw()
# Out:
# <div>
#
#
#             <div id="0e75d2ba-0cfa-4746-b5bc-5d2f3f58d26e" class="plotly-graph-div" style="height:450px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0e75d2ba-0cfa-4746-b5bc-5d2f3f58d26e")) {
#                     Plotly.newPlot(
#                         '0e75d2ba-0cfa-4746-b5bc-5d2f3f58d26e',
#                         [{"hoverinfo": "none", "line": {"color": "rgb(127, 127, 127)", "dash": "solid", "width": 0}, "mode": "lines", "type": "scatter", "x": [0.5692964441475084, 0.5692964441475084, null, 0, 1, null], "y": [0, 1, null, 0.4419933114889764, 0.4419933114889764, null]}, {"hoverinfo": "none", "line": {"color": "rgb(0, 0, 0)", "dash": "solid", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.6619372592221638, 0.6805075020285476, null, 0.6619372592221638, 0.46480853144386114, null, 0.6619372592221638, 0.4730070771582452, null, 0.6619372592221638, 0.3915647550591153, null, 0.6619372592221638, 0.5832537024052868, null, 0.6619372592221638, 0.5926438855892003, null, 0.6619372592221638, 0.4247268914487645, null, 0.6619372592221638, 0.4933635235703459, null, 0.6619372592221638, 0.5607476720975718, null, 0.6619372592221638, 0.4295462379444439, null, 0.6619372592221638, 0.6076672022806111, null, 0.6619372592221638, 0.579709786869585, null, 0.6619372592221638, 0.5193514512251074, null, 0.6619372592221638, 0.6294361807788563, null, 0.6619372592221638, 0.6477365411589131, null, 0.6619372592221638, 0.47950197695942176, null, 0.6619372592221638, 0.4941350917378616, null, 0.6619372592221638, 0.664456825804593, null, 0.6619372592221638, 0.40160495225255877, null, 0.6619372592221638, 0.48897590452797596, null, 0.6619372592221638, 0.4093092299782678, null, 0.6619372592221638, 0.4591594109203876, null, 0.6619372592221638, 0.4102683519045161, null, 0.6619372592221638, 0.4586942340146307, null, 0.6619372592221638, 0.49693227505851645, null, 0.6619372592221638, 0.5182294546732708, null, 0.6619372592221638, 0.5474936327037925, null, 0.6619372592221638, 0.28750105070716236, null, 0.6619372592221638, 0.3640291198858825, null, 0.6619372592221638, 0.6945845673795855, null, 0.6619372592221638, 0.6352881754508677, null, 0.6619372592221638, 0.5343647297378772, null, 0.6619372592221638, 0.504563359834073, null, 0.6619372592221638, 0.9667178481294234, null, 0.6619372592221638, 0.601181376915038, null, 0.6619372592221638, 0.5906645752683035, null, 0.6619372592221638, 0.5605425293339945, null, 0.6619372592221638, 0.4968912606939806, null, 0.6619372592221638, 0.60563448891755, null, 0.6619372592221638, 0.5447366504619716, null, 0.6619372592221638, 0.6388437021930803, null, 0.6619372592221638, 0.5323912926271406, null, 0.6619372592221638, 0.7654582390633812, null, 0.6619372592221638, 0.6176963586422048, null, 0.6619372592221638, 0.623955663293974, null, 0.6619372592221638, 0.6825722258471159, null, 0.6619372592221638, 0.5446573702757038, null, 0.6619372592221638, 0.6966756496705816, null, 0.6619372592221638, 0.7858151113917058, null, 0.6619372592221638, 0.5930301722519146, null, 0.6619372592221638, 0.5808482118921521, null, 0.6619372592221638, 0.7347693777904604, null, 0.6619372592221638, 0.5899689393966235, null, 0.6619372592221638, 0.7548312725347971, null, 0.6619372592221638, 0.6534271387653999, null, 0.6619372592221638, 0.7602952055238404, null, 0.6619372592221638, 0.7567954763455762, null, 0.6805075020285476, 0.5832537024052868, null, 0.6805075020285476, 0.579709786869585, null, 0.6805075020285476, 0.6076672022806111, null, 0.6805075020285476, 0.6477365411589131, null, 0.6805075020285476, 0.4933635235703459, null, 0.6805075020285476, 0.5607476720975718, null, 0.6805075020285476, 0.5926438855892003, null, 0.6805075020285476, 0.60563448891755, null, 0.6805075020285476, 0.46480853144386114, null, 0.6805075020285476, 0.4247268914487645, null, 0.6805075020285476, 0.4730070771582452, null, 0.6805075020285476, 0.3915647550591153, null, 0.6805075020285476, 0.4586942340146307, null, 0.6805075020285476, 0.6352881754508677, null, 0.6805075020285476, 0.5193514512251074, null, 0.6805075020285476, 0.4591594109203876, null, 0.6805075020285476, 0.4102683519045161, null, 0.6805075020285476, 0.7561013653085347, null, 0.6805075020285476, 0.49693227505851645, null, 0.6805075020285476, 0.623955663293974, null, 0.6805075020285476, 0.47950197695942176, null, 0. ...

# %%
df
# Out:
#                                    p-value
# Shapiro-Wilk (normal)             0.000000
# D'Agostino-Pearson (normal)       0.000000
# Kolmogorov-Smirnov (normal)       0.000023
# Kolmogorov-Smirnov (powerlaw)     0.000000
# Kolmogorov-Smirnov (exponential)  0.001954

# %% [markdown]
# ##### Calculando Betweenness para cada temporada

# %%
b_serie1 = nx.betweenness_centrality(s1)
b_serie2 = nx.betweenness_centrality(s2)
b_serie3 = nx.betweenness_centrality(s3)
b_serie4 = nx.betweenness_centrality(s4)
b_serie5 = nx.betweenness_centrality(s5)

c_serie1 = nx.closeness_centrality(s1)
c_serie2 = nx.closeness_centrality(s2)
c_serie3 = nx.closeness_centrality(s3)
c_serie4 = nx.closeness_centrality(s4)
c_serie5 = nx.closeness_centrality(s5)

p_serie1 = nx.pagerank(s1)
p_serie2 = nx.pagerank(s2)
p_serie3 = nx.pagerank(s3)
p_serie4 = nx.pagerank(s4)
p_serie5 = nx.pagerank(s5)

b_serie = [b_serie1, b_serie2, b_serie3, b_serie4, b_serie5]
c_serie = [c_serie1, c_serie2, c_serie3, c_serie4, c_serie5]
p_serie = [p_serie1, p_serie2, p_serie3, p_serie4, p_serie5]

for n in b_serie1:
    print(n, b_serie1[n])
# Out:
# NED 0.3006678156106007
# ROBERT 0.10989974270115796
# DAENERYS 0.10075782537259582
# JORAH 0.05342257003267803
# JON 0.08512842627581105
# SAM 0.03214407109645205
# LITTLEFINGER 0.015700379776754644
# VARYS 0.025424460116749734
# DROGO 0.02792989205938548
# ARYA 0.0656514696720996
# CATELYN 0.12327285973045146
# ROBB 0.07936180443779715
# BRONN 0.003618935859578387
# TYRION 0.16947408623776328
# CERSEI 0.017653407677459952
# SHAE 0.0
# JOFFREY 0.028549694663168344
# SANSA 0.01992488645309557
# PYCELLE 0.0020485680198614404
# VISERYS 0.00624781757694564
# SEPTA_MORDANE 0.00020076043885567695
# TYWIN 0.026441333439792717
# JEOR 0.03534751985568738
# THEON 0.02956314399888157
# BRAN 0.0258184376805872
# MAESTER_LUWIN 0.002503716741622247
# JAIME 0.020701269829928558
# LORAS 0.015914285714285714
# RENLY 0.005546062361290171
# MIRRI_MAZ_DUUR 0.0
# SYRIO_FOREL 0.0
# JORY_CASSEL 0.0014212018917901267
# PYP 0.06035146783454571
# ROS 0.0005410368621337217
# GRENN 0.0018844163396352692
# WALDER 0.0332172335600907
# DOREAH 0.016318883108799073
# BENJEN 0.0006162146495597135
# IRRI 0.0003612111511271175
# GREATJON_UMBER 0.00972092880909577
# MORD 0.0005456065254384582
# LYSA 0.001249860353990244
# RAKHARO 0.0003386243386243385
# ROBIN 0.0007721237322760309
# OSHA 0.00019778739778739777
# RODRIK 0.004270696512599359
# QOTHO 0.0
# MAESTER_AEMON 0.009538624805938678
# BARRISTAN 0.0004857891833241974
# ILLYRIO 0.002985958641420827
# SHAGGA 0.0
# YOREN 0.003489847405361772
# ALLISER_THORNE 0.00023078861174099266
# WINE_MERCHANT 4.232804232804232e-05
# HOUND 0.006224920953631477
# LANCEL 0.0
# RICKON 0.0
# MARILLION 0.000931126717814634
# KEVAN 0.0022026161050537206
# VARDIS_EGEN 0.0
# RHAEGO 0.0
# JANOS 0.0
# GENDRY 0.0023450926291262424
# HOT_PIE 0.00010582010582010581
# LOMMY_GREENHANDS 0.0
# MERYN_TRANT 0.0009570465598846362
# JON_ARRYN 0.004130105726242615
# HODOR 0.00038138728515847784
# STANNIS 0.0009146609381903501
# MAGO 0.0
# MYCAH 0.0
# TOBHO_MOTT 0.0
# RAST 0.0018662757500661083
# OLD_NAN 0.0
# MHAEGEN 0.0
# VARDIS_EGAN 0.0
# AERYS 0.02232773504435532
# BAELOR 2.998236331569665e-05
# DAREON 0.00602936992460802
# STABLE_BOY 0.0
# HUGH_OF_THE_VALE 0.00015863758608856648
# OTHELL_YARWYCK 0.0006276831849615802
# OTHOR 0.0
# MOUNTAIN 0.0001887125220458554
# TOMARD 0.0
# GARED 0.0
# ROYCE 0.0
# JONOS_BRACKEN 0.0
# MASHA_HEDDLE 0.0
# RICKARD_STARK 0.00014230284706475183
# ILYN_PAYNE 8.163265306122448e-05
# WILL 0.047148265366752755
# LYANNA 0.0
# RYGER_RIVERS 0.0
# STEVRON_FREY 0.0
# WAYMAR_ROYCE 0.0
# ADDAM_MARBRAND 6.56084656084656e-05
# LEO_LEFFORD 0.0010024587252330523
# RHAEGAR 0.0
# ASSASSIN 0.0
# BALON 0.0
# BERIC 0.0
# BRANDON_STARK 0.000642685356971071
# HOSTER 0.0
# COHOLLO 0.0
# JHIQUI 0.0
# MYRCELLA 0.0
# AEGON 0.0
# BORCAS 0.0
# BOWEN_MARSH 0.0
# LUKE 0.0
# IROGENIA 0.0
# GALBART_GLOVER 6.349206349206349e-05
# RICKARD_KARSTARK 0.0
# HIGH_SEPTON 0.0
# TYSHA 0.0
# JAREMY_RYKKER 0.0
# JOANNA 0.0
# TOMMEN 0.0
# LITTLE_BIRD 0.0
# JOYEUSE 0.0
# MACE 0.0
# MELESSA 0.0
# ROOSE_BOLTON 0.0
# STEFFON 0.0
# VARLY 0.0
# RANDYLL 0.0

# %%
personagem_b_serie = []
for b in b_serie:
    personagem_b_serie.append(b["TYRION"])
    
print("TYRION - Betweenness:", personagem_b_serie)

personagem_c_serie = []
for c in c_serie:
    personagem_c_serie.append(c["TYRION"])
    
print("TYRION - Closeness:", personagem_c_serie)

personagem_p_serie = []
for p in p_serie:
    personagem_p_serie.append(p["TYRION"])
    
print("TYRION - Pagerrank:", personagem_p_serie)
# Out:
# TYRION - Betweenness: [0.16947408623776328, 0.14278938847830466, 0.09865173199290381, 0.09095759740305433, 0.12635168545615638]
# TYRION - Closeness: [0.5431034482758621, 0.4787776527934008, 0.41694915254237286, 0.4065335753176043, 0.3881578947368421]
# TYRION - Pagerrank: [0.05004312439830023, 0.058644052888662375, 0.03998236417824795, 0.04036703404535525, 0.032758944911689104]

# %% [markdown]
# ##### Calculando e Inserindo centralidades no grafo

# %%
def calcula_metricas(g1):
    g1.set_nodedata('betweenness', nx.betweenness_centrality(g1))
    g1.set_nodedata('closeness', nx.closeness_centrality(g1))
    g1.set_nodedata('pagerank', nx.pagerank(g1))

    


calcula_metricas(s1)
calcula_metricas(s2)
calcula_metricas(s3)
calcula_metricas(s4)
calcula_metricas(s5)
s1.nodeframe.head()
# Out:
#           degree  betweenness  closeness  pagerank
# NED           57     0.300668   0.626866  0.081778
# ROBERT        36     0.109900   0.552632  0.034330
# DAENERYS      18     0.100758   0.454874  0.036101
# JORAH         15     0.053423   0.431507  0.020155
# JON           26     0.085128   0.518519  0.038775

# %% [markdown]
# ##### Analises de redes para o Personagem: Tyrion Lannister

# %% [markdown]
# <img src="tyrion.jpg" width="200" height="200" align="left" />

# %%
#s1.scaplot_nodes('outdegree', 'hub')
import matplotlib.pyplot as plt

lista = [1, 2, 3, 4, 5]
fig, ax = plt.subplots()
plt.scatter(personagem_b_serie, personagem_b_livro)
plt.title('Scatter plot TYRION - Betweenness Livro x Serie')
plt.xlabel('serie')
plt.ylabel('livro')

for i, txt in enumerate(lista):
    ax.annotate(txt, (personagem_b_serie[i]+0.0013, personagem_b_livro[i]))

plt.show()

# %%
fig, ax = plt.subplots()
plt.scatter(personagem_c_serie, personagem_c_livro)
plt.title('Scatter plot TYRION - Closeness Livro x Serie')
plt.xlabel('serie')
plt.ylabel('livro')

for i, txt in enumerate(lista):
    ax.annotate(txt, (personagem_c_serie[i]+0.002, personagem_c_livro[i]))

plt.show()

# %%
fig, ax = plt.subplots()
plt.scatter(personagem_p_serie, personagem_p_livro)
plt.title('Scatter plot TYRION - Pagerank Livro x Serie')
plt.xlabel('serie')
plt.ylabel('livro')

for i, txt in enumerate(lista):
    ax.annotate(txt, (personagem_p_serie[i]+0.0009, personagem_p_livro[i]))

plt.show()

# %% [markdown]
# ##### Analises de redes para os personagens mais importantes

# %%
for index, row in tabela_total.iterrows():
    print(row)
    print(index)
    print('___________')
# Out:
# degree         2.000000
# betweenness    0.000000
# closeness      0.323944
# pagerank       0.001287
# Name: ADDAM_MARBRAND, dtype: float64
# ADDAM_MARBRAND
# ___________
# degree         29.000000
# betweenness     0.032362
# closeness       0.462312
# pagerank        0.014458
# Name: JAIME, dtype: float64
# JAIME
# ___________
# degree         22.000000
# betweenness     0.026605
# closeness       0.449878
# pagerank        0.011474
# Name: TYWIN, dtype: float64
# TYWIN
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.377049
# pagerank       0.001266
# Name: AEGON, dtype: float64
# AEGON
# ___________
# degree         21.000000
# betweenness     0.087282
# closeness       0.406181
# pagerank        0.027367
# Name: DAENERYS, dtype: float64
# DAENERYS
# ___________
# degree         66.000000
# betweenness     0.271531
# closeness       0.564417
# pagerank        0.072635
# Name: NED, dtype: float64
# NED
# ___________
# degree         7.000000
# betweenness    0.010964
# closeness      0.336996
# pagerank       0.005854
# Name: MAESTER_AEMON, dtype: float64
# MAESTER_AEMON
# ___________
# degree         10.000000
# betweenness     0.004998
# closeness       0.362919
# pagerank        0.005390
# Name: ALLISER_THORNE, dtype: float64
# ALLISER_THORNE
# ___________
# degree         5.000000
# betweenness    0.000000
# closeness      0.335766
# pagerank       0.002379
# Name: BOWEN_MARSH, dtype: float64
# BOWEN_MARSH
# ___________
# degree         3.000000
# betweenness    0.000000
# closeness      0.333333
# pagerank       0.001961
# Name: CHETT, dtype: float64
# CHETT
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.252401
# pagerank       0.001147
# Name: CLYDAS, dtype: float64
# CLYDAS
# ___________
# degree         13.000000
# betweenness     0.028458
# closeness       0.415350
# pagerank        0.011683
# Name: JEOR, dtype: float64
# JEOR
# ___________
# degree         37.000000
# betweenness     0.173513
# closeness       0.493298
# pagerank        0.047938
# Name: JON, dtype: float64
# JON
# ___________
# degree         12.000000
# betweenness     0.014648
# closeness       0.357977
# pagerank        0.009775
# Name: SAM, dtype: float64
# SAM
# ___________
# degree         6.000000
# betweenness    0.000440
# closeness      0.385744
# pagerank       0.003042
# Name: AERYS, dtype: float64
# AERYS
# ___________
# degree         6.000000
# betweenness    0.000348
# closeness      0.382536
# pagerank       0.002906
# Name: BRANDON, dtype: float64
# BRANDON
# ___________
# degree         5.000000
# betweenness    0.021680
# closeness      0.380952
# pagerank       0.003870
# Name: GEROLD-HIGHTOWER, dtype: float64
# GEROLD-HIGHTOWER
# ___________
# degree         15.000000
# betweenness     0.012608
# closeness       0.437055
# pagerank        0.009660
# Name: JON_ARRYN, dtype: float64
# JON_ARRYN
# ___________
# degree         50.000000
# betweenness     0.215499
# closeness       0.545994
# pagerank        0.048683
# Name: ROBERT, dtype: float64
# ROBERT
# ___________
# degree         6.000000
# betweenness    0.000074
# closeness      0.293461
# pagerank       0.003156
# Name: AGGO, dtype: float64
# AGGO
# ___________
# degree         19.000000
# betweenness     0.065435
# closeness       0.380165
# pagerank        0.017649
# Name: DROGO, dtype: float64
# DROGO
# ___________
# degree         6.000000
# betweenness    0.000045
# closeness      0.293461
# pagerank       0.003242
# Name: JHOGO, dtype: float64
# JHOGO
# ___________
# degree         13.000000
# betweenness     0.012708
# closeness       0.374745
# pagerank        0.009320
# Name: JORAH, dtype: float64
# JORAH
# ___________
# degree         5.000000
# betweenness    0.000030
# closeness      0.292994
# pagerank       0.002259
# Name: QUARO, dtype: float64
# QUARO
# ___________
# degree         5.000000
# betweenness    0.000035
# closeness      0.292994
# pagerank       0.002531
# Name: RAKHARO, dtype: float64
# RAKHARO
# ___________
# degree         3.000000
# betweenness    0.000000
# closeness      0.332130
# pagerank       0.001498
# Name: ALBETT, dtype: float64
# ALBETT
# ___________
# degree         8.000000
# betweenness    0.000215
# closeness      0.335766
# pagerank       0.004132
# Name: HALDER, dtype: float64
# HALDER
# ___________
# degree         6.000000
# betweenness    0.000079
# closeness      0.334545
# pagerank       0.002435
# Name: RAST, dtype: float64
# RAST
# ___________
# degree         7.000000
# betweenness    0.000207
# closeness      0.336380
# pagerank       0.005535
# Name: GRENN, dtype: float64
# GRENN
# ___________
# degree         7.000000
# betweenness    0.000076
# closeness      0.335155
# pagerank       0.006859
# Name: PYPAR, dtype: float64
# PYPAR
# ___________
# degree         45.000000
# betweenness     0.188287
# closeness       0.509695
# pagerank        0.043104
# Name: TYRION, dtype: float64
# TYRION
# ___________
# degree         5.000000
# betweenness    0.000321
# closeness      0.380952
# pagerank       0.002676
# Name: ALYN, dtype: float64
# ALYN
# ___________
# degree         4.000000
# betweenness    0.000323
# closeness      0.365079
# pagerank       0.001937
# Name: HARWIN, dtype: float64
# HARWIN
# ___________
# degree         21.000000
# betweenness     0.017715
# closeness       0.437055
# pagerank        0.009469
# Name: JORY_CASSEL, dtype: float64
# JORY_CASSEL
# ___________
# degree         7.000000
# betweenness    0.000303
# closeness      0.375510
# pagerank       0.003097
# Name: TOMARD, dtype: float64
# TOMARD
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.276276
# pagerank       0.001585
# Name: ARTHUR-DAYNE, dtype: float64
# ARTHUR-DAYNE
# ___________
# degree         27.000000
# betweenness     0.017675
# closeness       0.457711
# pagerank        0.021600
# Name: ARYA, dtype: float64
# ARYA
# ___________
# degree         14.000000
# betweenness     0.033288
# closeness       0.431925
# pagerank        0.007224
# Name: BENJEN, dtype: float64
# BENJEN
# ___________
# degree         31.000000
# betweenness     0.047900
# closeness       0.485488
# pagerank        0.029257
# Name: BRAN, dtype: float64
# BRAN
# ___________
# degree         42.000000
# betweenness     0.149400
# closeness       0.504110
# pagerank        0.034533
# Name: CATELYN, dtype: float64
# CATELYN
# ___________
# degree         30.000000
# betweenness     0.026691
# closeness       0.484211
# pagerank        0.021713
# Name: CERSEI, dtype: float64
# CERSEI
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.368737
# pagerank       0.001131
# Name: DESMOND, dtype: float64
# DESMOND
# ___________
# degree         9.000000
# betweenness    0.000327
# closeness      0.387368
# pagerank       0.002764
# Name: ILYN_PAYNE, dtype: float64
# ILYN_PAYNE
# ___________
# degree         6.000000
# betweenness    0.000062
# closeness      0.365079
# pagerank       0.003225
# Name: JEYNE-POOLE, dtype: float64
# JEYNE-POOLE
# ___________
# degree         30.000000
# betweenness     0.019086
# closeness       0.480418
# pagerank        0.020766
# Name: JOFFREY, dtype: float64
# JOFFREY
# ___________
# degree         9.000000
# betweenness    0.000714
# closeness      0.368000
# pagerank       0.002584
# Name: MERYN_TRANT, dtype: float64
# MERYN_TRANT
# ___________
# degree         11.000000
# betweenness     0.001079
# closeness       0.407080
# pagerank        0.007095
# Name: MORDANE, dtype: float64
# MORDANE
# ___________
# degree         5.000000
# betweenness    0.000000
# closeness      0.373225
# pagerank       0.002968
# Name: MYCAH, dtype: float64
# MYCAH
# ___________
# degree         7.000000
# betweenness    0.000029
# closeness      0.366534
# pagerank       0.003210
# Name: MYRCELLA, dtype: float64
# MYRCELLA
# ___________
# degree         26.000000
# betweenness     0.009203
# closeness       0.456576
# pagerank        0.016207
# Name: LITTLEFINGER, dtype: float64
# LITTLEFINGER
# ___________
# degree         9.000000
# betweenness    0.000092
# closeness      0.439141
# pagerank       0.005525
# Name: RICKON, dtype: float64
# RICKON
# ___________
# degree         35.000000
# betweenness     0.074073
# closeness       0.497297
# pagerank        0.029239
# Name: ROBB, dtype: float64
# ROBB
# ___________
# degree         18.000000
# betweenness     0.009714
# closeness       0.453202
# pagerank        0.007599
# Name: RODRIK, dtype: float64
# RODRIK
# ___________
# degree         16.000000
# betweenness     0.006322
# closeness       0.415350
# pagerank        0.007523
# Name: HOUND, dtype: float64
# HOUND
# ___________
# degree         35.000000
# betweenness     0.037450
# closeness       0.489362
# pagerank        0.027075
# Name: SANSA, dtype: float64
# SANSA
# ___________
# degree         3.000000
# betweenness    0.000126
# closeness      0.370221
# pagerank       0.002258
# Name: SYRIO_FOREL, dtype: float64
# SYRIO_FOREL
# ___________
# degree         8.000000
# betweenness    0.000553
# closeness      0.392324
# pagerank       0.002523
# Name: TOMMEN, dtype: float64
# TOMMEN
# ___________
# degree         5.000000
# betweenness    0.000000
# closeness      0.383333
# pagerank       0.002129
# Name: VAYON-POOLE, dtype: float64
# VAYON-POOLE
# ___________
# degree         7.000000
# betweenness    0.000216
# closeness      0.384134
# pagerank       0.002552
# Name: YOREN, dtype: float64
# YOREN
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.326821
# pagerank       0.000941
# Name: ARYS-OAKHEART, dtype: float64
# ARYS-OAKHEART
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.377049
# pagerank       0.001131
# Name: BALON, dtype: float64
# BALON
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.305648
# pagerank       0.001087
# Name: BALON-SWANN, dtype: float64
# BALON-SWANN
# ___________
# degree         18.000000
# betweenness     0.009657
# closeness       0.433962
# pagerank        0.009797
# Name: RENLY, dtype: float64
# RENLY
# ___________
# degree         14.000000
# betweenness     0.001263
# closeness       0.394004
# pagerank        0.007358
# Name: BARRISTAN, dtype: float64
# BARRISTAN
# ___________
# degree         5.000000
# betweenness    0.000000
# closeness      0.339483
# pagerank       0.002017
# Name: BOROS, dtype: float64
# BOROS
# ___________
# degree         14.000000
# betweenness     0.000328
# closeness       0.399132
# pagerank        0.007701
# Name: PYCELLE, dtype: float64
# PYCELLE
# ___________
# degree         17.000000
# betweenness     0.010885
# closeness       0.446602
# pagerank        0.011545
# Name: VARYS, dtype: float64
# VARYS
# ___________
# degree         4.000000
# betweenness    0.010870
# closeness      0.335766
# pagerank       0.002907
# Name: JAREMY_RYKKER, dtype: float64
# JAREMY_RYKKER
# ___________
# degree         18.000000
# betweenness     0.013396
# closeness       0.448780
# pagerank        0.012127
# Name: LUWIN, dtype: float64
# LUWIN
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.302135
# pagerank       0.000988
# Name: MANCE, dtype: float64
# MANCE
# ___________
# degree         15.000000
# betweenness     0.009885
# closeness       0.449878
# pagerank        0.007957
# Name: THEON, dtype: float64
# THEON
# ___________
# degree         3.000000
# betweenness    0.006796
# closeness      0.304132
# pagerank       0.004812
# Name: WAYMAR_ROYCE, dtype: float64
# WAYMAR_ROYCE
# ___________
# degree         6.000000
# betweenness    0.010870
# closeness      0.384134
# pagerank       0.003109
# Name: BERIC, dtype: float64
# BERIC
# ___________
# degree         12.000000
# betweenness     0.002956
# closeness       0.419134
# pagerank        0.005225
# Name: MOUNTAIN, dtype: float64
# MOUNTAIN
# ___________
# degree         14.000000
# betweenness     0.022663
# closeness       0.399132
# pagerank        0.005787
# Name: LORAS, dtype: float64
# LORAS
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.277946
# pagerank       0.001283
# Name: THOROS, dtype: float64
# THOROS
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.327402
# pagerank       0.000952
# Name: HALI, dtype: float64
# HALI
# ___________
# degree         5.000000
# betweenness    0.000000
# closeness      0.353846
# pagerank       0.002699
# Name: HALLIS-MOLLEN, dtype: float64
# HALLIS-MOLLEN
# ___________
# degree         4.000000
# betweenness    0.000000
# closeness      0.340741
# pagerank       0.003415
# Name: HODOR, dtype: float64
# HODOR
# ___________
# degree         6.000000
# betweenness    0.000446
# closeness      0.351145
# pagerank       0.001939
# Name: HULLEN, dtype: float64
# HULLEN
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.327986
# pagerank       0.001147
# Name: JOSETH, dtype: float64
# JOSETH
# ___________
# degree         4.000000
# betweenness    0.000000
# closeness      0.340741
# pagerank       0.002449
# Name: NAN, dtype: float64
# NAN
# ___________
# degree         3.000000
# betweenness    0.000000
# closeness      0.340111
# pagerank       0.002307
# Name: OSHA, dtype: float64
# OSHA
# ___________
# degree         11.000000
# betweenness     0.010213
# closeness       0.406181
# pagerank        0.004073
# Name: RICKARD, dtype: float64
# RICKARD
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.339483
# pagerank       0.001144
# Name: STIV, dtype: float64
# STIV
# ___________
# degree         4.000000
# betweenness    0.000034
# closeness      0.380165
# pagerank       0.002530
# Name: LYANNA, dtype: float64
# LYANNA
# ___________
# degree         10.000000
# betweenness     0.004215
# closeness       0.370968
# pagerank        0.008135
# Name: BRONN, dtype: float64
# BRONN
# ___________
# degree         3.000000
# betweenness    0.000000
# closeness      0.339483
# pagerank       0.001841
# Name: CHIGGEN, dtype: float64
# CHIGGEN
# ___________
# degree         5.000000
# betweenness    0.000000
# closeness      0.361493
# pagerank       0.002553
# Name: MARILLION, dtype: float64
# MARILLION
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.338858
# pagerank       0.001687
# Name: SHAE, dtype: float64
# SHAE
# ___________
# degree         6.000000
# betweenness    0.021828
# closeness      0.343284
# pagerank       0.006694
# Name: SHAGGA, dtype: float64
# SHAGGA
# ___________
# degree         6.000000
# betweenness    0.001214
# closeness      0.359375
# pagerank       0.003646
# Name: VARDIS_EGEN, dtype: float64
# VARDIS_EGEN
# ___________
# degree         6.000000
# betweenness    0.000396
# closeness      0.362205
# pagerank       0.002598
# Name: WILLIS-WODE, dtype: float64
# WILLIS-WODE
# ___________
# degree         11.000000
# betweenness     0.003916
# closeness       0.384134
# pagerank        0.005260
# Name: BRYNDEN, dtype: float64
# BRYNDEN
# ___________
# degree         11.000000
# betweenness     0.019832
# closeness       0.405286
# pagerank        0.004978
# Name: EDMURE, dtype: float64
# EDMURE
# ___________
# degree         5.000000
# betweenness    0.000399
# closeness      0.383333
# pagerank       0.002404
# Name: HOSTER, dtype: float64
# HOSTER
# ___________
# degree         14.000000
# betweenness     0.016968
# closeness       0.428904
# pagerank        0.009164
# Name: LYSA, dtype: float64
# LYSA
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.336380
# pagerank       0.001176
# Name: NESTOR-ROYCE, dtype: float64
# NESTOR-ROYCE
# ___________
# degree         7.000000
# betweenness    0.032691
# closeness      0.360078
# pagerank       0.004266
# Name: WALDER, dtype: float64
# WALDER
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.336380
# pagerank       0.001316
# Name: COLEMON, dtype: float64
# COLEMON
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.335766
# pagerank       0.000981
# Name: DONNEL_WAYNWOOD, dtype: float64
# DONNEL_WAYNWOOD
# ___________
# degree         3.000000
# betweenness    0.000000
# closeness      0.338235
# pagerank       0.001412
# Name: EON, dtype: float64
# EON
# ___________
# degree         8.000000
# betweenness    0.003328
# closeness      0.358674
# pagerank       0.003698
# Name: GREATJON_UMBER, dtype: float64
# GREATJON_UMBER
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.335766
# pagerank       0.001095
# Name: MASHA_HEDDLE, dtype: float64
# MASHA_HEDDLE
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.335766
# pagerank       0.000981
# Name: MOREO-TUMITIS, dtype: float64
# MOREO-TUMITIS
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.335766
# pagerank       0.001322
# Name: MYA-STONE, dtype: float64
# MYA-STONE
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.335766
# pagerank       0.000981
# Name: MYCHEL-REDFORT, dtype: float64
# MYCHEL-REDFORT
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.338235
# pagerank       0.001360
# Name: STEVRON_FREY, dtype: float64
# STEVRON_FREY
# ___________
# degree         3.000000
# betweenness    0.010870
# closeness      0.339483
# pagerank       0.002543
# Name: TYTOS-BLACKWOOD, dtype: float64
# TYTOS-BLACKWOOD
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.348485
# pagerank       0.001126
# Name: WENDEL-MANDERLY, dtype: float64
# WENDEL-MANDERLY
# ___________
# degree         3.000000
# betweenness    0.000022
# closeness      0.363636
# pagerank       0.001658
# Name: CAYN, dtype: float64
# CAYN
# ___________
# degree         7.000000
# betweenness    0.000000
# closeness      0.383333
# pagerank       0.001910
# Name: JANOS, dtype: float64
# JANOS
# ___________
# degree         12.000000
# betweenness     0.000447
# closeness       0.401747
# pagerank        0.005676
# Name: STANNIS, dtype: float64
# STANNIS
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.338235
# pagerank       0.001097
# Name: CHELLA, dtype: float64
# CHELLA
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.225767
# pagerank       0.001732
# Name: CLEMENT-PIPER, dtype: float64
# CLEMENT-PIPER
# ___________
# degree         3.000000
# betweenness    0.010870
# closeness      0.291139
# pagerank       0.002981
# Name: KARYLANCE, dtype: float64
# KARYLANCE
# ___________
# degree         4.000000
# betweenness    0.000000
# closeness      0.292528
# pagerank       0.002558
# Name: COHOLLO, dtype: float64
# COHOLLO
# ___________
# degree         6.000000
# betweenness    0.000069
# closeness      0.293461
# pagerank       0.003623
# Name: HAGGO, dtype: float64
# HAGGO
# ___________
# degree         7.000000
# betweenness    0.000119
# closeness      0.293930
# pagerank       0.004976
# Name: QOTHO, dtype: float64
# QOTHO
# ___________
# degree         3.000000
# betweenness    0.010870
# closeness      0.341373
# pagerank       0.003671
# Name: CONN, dtype: float64
# CONN
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.254848
# pagerank       0.001591
# Name: CORATT, dtype: float64
# CORATT
# ___________
# degree         6.000000
# betweenness    0.000012
# closeness      0.293461
# pagerank       0.003641
# Name: DOREAH, dtype: float64
# DOREAH
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.289308
# pagerank       0.001073
# Name: EROEH, dtype: float64
# EROEH
# ___________
# degree         6.000000
# betweenness    0.001207
# closeness      0.369478
# pagerank       0.004534
# Name: ILLYRIO, dtype: float64
# ILLYRIO
# ___________
# degree         8.000000
# betweenness    0.000098
# closeness      0.294400
# pagerank       0.005402
# Name: IRRI, dtype: float64
# IRRI
# ___________
# degree         5.000000
# betweenness    0.000000
# closeness      0.292994
# pagerank       0.004136
# Name: JHIQUI, dtype: float64
# JHIQUI
# ___________
# degree         6.000000
# betweenness    0.000049
# closeness      0.293461
# pagerank       0.004357
# Name: MIRRI_MAZ_DUUR, dtype: float64
# MIRRI_MAZ_DUUR
# ___________
# degree         7.000000
# betweenness    0.002878
# closeness      0.400871
# pagerank       0.003329
# Name: RHAEGAR, dtype: float64
# RHAEGAR
# ___________
# degree         8.000000
# betweenness    0.002879
# closeness      0.370968
# pagerank       0.006450
# Name: VISERYS, dtype: float64
# VISERYS
# ___________
# degree         3.000000
# betweenness    0.021620
# closeness      0.266667
# pagerank       0.003937
# Name: DANWELL, dtype: float64
# DANWELL
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.211009
# pagerank       0.003359
# Name: HOSTEEN, dtype: float64
# HOSTEEN
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.211009
# pagerank       0.003359
# Name: JARED, dtype: float64
# JARED
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.330935
# pagerank       0.001123
# Name: DAREON, dtype: float64
# DAREON
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.362205
# pagerank       0.001367
# Name: DARYN-HORNWOOD, dtype: float64
# DARYN-HORNWOOD
# ___________
# degree         3.000000
# betweenness    0.000278
# closeness      0.378601
# pagerank       0.001777
# Name: TORRHEN, dtype: float64
# TORRHEN
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.255911
# pagerank       0.001717
# Name: DOLF, dtype: float64
# DOLF
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.330935
# pagerank       0.001175
# Name: DONAL-NOYE, dtype: float64
# DONAL-NOYE
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.276692
# pagerank       0.001453
# Name: JOMMO, dtype: float64
# JOMMO
# ___________
# degree         3.000000
# betweenness    0.010870
# closeness      0.277108
# pagerank       0.003290
# Name: OGO, dtype: float64
# OGO
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.275862
# pagerank       0.001104
# Name: RHAEGO, dtype: float64
# RHAEGO
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.330935
# pagerank       0.001019
# Name: DYWEN, dtype: float64
# DYWEN
# ___________
# degree         6.000000
# betweenness    0.000871
# closeness      0.384134
# pagerank       0.002273
# Name: GALBART_GLOVER, dtype: float64
# GALBART_GLOVER
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.361493
# pagerank       0.000955
# Name: GENDRY, dtype: float64
# GENDRY
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.365079
# pagerank       0.001170
# Name: HIGH_SEPTON, dtype: float64
# HIGH_SEPTON
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.361493
# pagerank       0.000955
# Name: HOWLAND, dtype: float64
# HOWLAND
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.361493
# pagerank       0.001003
# Name: JACKS, dtype: float64
# JACKS
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.361493
# pagerank       0.001051
# Name: JOSS, dtype: float64
# JOSS
# ___________
# degree         5.000000
# betweenness    0.006344
# closeness      0.376278
# pagerank       0.002432
# Name: MARQ-PIPER, dtype: float64
# MARQ-PIPER
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.361493
# pagerank       0.001003
# Name: PORTHER, dtype: float64
# PORTHER
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.377049
# pagerank       0.001355
# Name: RAYMUN-DARRY, dtype: float64
# RAYMUN-DARRY
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.361493
# pagerank       0.001147
# Name: TOBHO_MOTT, dtype: float64
# TOBHO_MOTT
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.361493
# pagerank       0.001003
# Name: TREGAR, dtype: float64
# TREGAR
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.361493
# pagerank       0.001003
# Name: VARLY, dtype: float64
# VARLY
# ___________
# degree         4.000000
# betweenness    0.001655
# closeness      0.368000
# pagerank       0.001870
# Name: WYL-(GUARD), dtype: float64
# WYL-(GUARD)
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.361493
# pagerank       0.000955
# Name: WYLLA, dtype: float64
# WYLLA
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.217237
# pagerank       0.001432
# Name: FOGO, dtype: float64
# FOGO
# ___________
# degree         5.000000
# betweenness    0.000025
# closeness      0.343284
# pagerank       0.002021
# Name: ROOSE_BOLTON, dtype: float64
# ROOSE_BOLTON
# ___________
# degree         3.000000
# betweenness    0.004364
# closeness      0.295820
# pagerank       0.004102
# Name: GARED, dtype: float64
# GARED
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.236200
# pagerank       0.004424
# Name: WILL-(PROLOGUE), dtype: float64
# WILL-(PROLOGUE)
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.276276
# pagerank       0.001392
# Name: OSWELL-WHENT, dtype: float64
# OSWELL-WHENT
# ___________
# degree         4.000000
# betweenness    0.000000
# closeness      0.332731
# pagerank       0.002498
# Name: TODDER, dtype: float64
# TODDER
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.338235
# pagerank       0.001211
# Name: GUNTHOR-SON-OF-GURN, dtype: float64
# GUNTHOR-SON-OF-GURN
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.316695
# pagerank       0.000964
# Name: HARYS-SWYFT, dtype: float64
# HARYS-SWYFT
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.305141
# pagerank       0.001393
# Name: HEWARD, dtype: float64
# HEWARD
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.330935
# pagerank       0.001071
# Name: HOBB, dtype: float64
# HOBB
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.304636
# pagerank       0.000957
# Name: HUGH, dtype: float64
# HUGH
# ___________
# degree         1.00000
# betweenness    0.00000
# closeness      0.25171
# pagerank       0.00112
# Name: JAFER-FLOWERS, dtype: float64
# JAFER-FLOWERS
# ___________
# degree         3.000000
# betweenness    0.000000
# closeness      0.356589
# pagerank       0.002357
# Name: KEVAN, dtype: float64
# KEVAN
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.330935
# pagerank       0.000967
# Name: MATTHAR, dtype: float64
# MATTHAR
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.330935
# pagerank       0.001071
# Name: OTHOR, dtype: float64
# OTHOR
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.290679
# pagerank       0.001426
# Name: MAEGE, dtype: float64
# MAEGE
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.253793
# pagerank       0.001459
# Name: JONOS_BRACKEN, dtype: float64
# JONOS_BRACKEN
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.338858
# pagerank       0.001938
# Name: JYCK, dtype: float64
# JYCK
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.338858
# pagerank       0.001846
# Name: MORREC, dtype: float64
# MORREC
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.338235
# pagerank       0.001097
# Name: KURLEKET, dtype: float64
# KURLEKET
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.353846
# pagerank       0.000943
# Name: LANCEL, dtype: float64
# LANCEL
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.338235
# pagerank       0.001039
# Name: LEO_LEFFORD, dtype: float64
# LEO_LEFFORD
# ___________
# degree         2.000000
# betweenness    0.010870
# closeness      0.286604
# pagerank       0.002645
# Name: MACE, dtype: float64
# MACE
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.300654
# pagerank       0.000991
# Name: LYN-CORBRAY, dtype: float64
# LYN-CORBRAY
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.223030
# pagerank       0.001936
# Name: PAXTER-REDWYNE, dtype: float64
# PAXTER-REDWYNE
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.329159
# pagerank       0.000980
# Name: MAEGOR, dtype: float64
# MAEGOR
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.338235
# pagerank       0.001954
# Name: MORD, dtype: float64
# MORD
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.263989
# pagerank       0.001092
# Name: RANDYLL, dtype: float64
# RANDYLL
# ___________
# degree         2.000000
# betweenness    0.000000
# closeness      0.340111
# pagerank       0.001500
# Name: TIMETT, dtype: float64
# TIMETT
# ___________
# degree         1.000000
# betweenness    0.000000
# closeness      0.255911
# pagerank       0.001328
# Name: ULF-SON-OF-UMAR, dtype: float64
# ULF-SON-OF-UMAR
# ___________

# %%
tabela_total.columns
# Out:
# Index(['degree', 'betweenness', 'closeness', 'pagerank'], dtype='object')

# %%
personagem_b_serie = []
personagem_b_livro = []
i = 0
for b in b_serie:
    
    #print(b['NED'])
    for k in b.keys():
        #print(b_livro[i])
        if(k in b_livro[i]):
            personagem_b_serie.append(b[k])
            personagem_b_livro.append(b_livro[i][k])
    i +=1

# %%
lista = [1, 2, 3, 4, 5]
fig, ax = plt.subplots()
plt.scatter(personagem_b_serie, personagem_b_livro)
plt.title('Scatter plot TYRION - Betweenness Livro x Serie')
plt.xlabel('serie')
plt.ylabel('livro')

for i, txt in enumerate(lista):
    ax.annotate(txt, (personagem_b_serie[i]+0.0013, personagem_b_livro[i]))

plt.show()
